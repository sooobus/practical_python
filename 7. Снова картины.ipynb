# %% [markdown]
# <a href="https://colab.research.google.com/github/sooobus/practical_python/blob/master/7.%20%D0%A1%D0%BD%D0%BE%D0%B2%D0%B0%20%D0%BA%D0%B0%D1%80%D1%82%D0%B8%D0%BD%D1%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Об этих заданиях
#
# В отличие от предыдущих заданий, этот листок предполагает командную работу в группах по 3 человека. Каждый выполнит свою часть заданий, которые будут объединены друг с другом.
#
# ## Роли
#
# * Разработка бэкенда чат-бота (соединение программы, которую напишут другие участники, с конечным пользователем -- разработка интерфейса бота). Challenges: нужно самостоятельно разобраться в библиотеке.
# * Разработка скрипта для взаимодействия с веб-сайтом: потребуется реализовать класс, который будет скачивать страницы с веб-сайта, обрабатывать их и извлекать нужную информацию. Challenges: нужно аккуратно и вовремя написать скрипт.
# * Разработка простой рекомендательной системы для определения того, какие посты дальше посылать пользователю. Challenges: хочется использовать интересную модель ML, для этого скорее всего придётся разобраться с scikit-learn
#
# ## Контекст задачи
# Необходимо разработать чат-бота, который будет спрашивать пользователя о том, какие картины ему нравятся, и с некоторой периодичностью присылать похожие картины и, возможно, информацию о художниках или эпохах. Дальнейшие детали остаются на усмотрение вашей команды. Оценивается сложность реализованных задач и интересность взаимодействия с ботом.

# %% [markdown]
# Дальше задания будут разделены в зависимости от вашей роли в команде.
#
# Обратите внимание, что, несмотря на то, что ниже есть примерные инструкции для каждого члена команды, вам необходимо договориться между собой, как соединить ваш код в единое целое. Наиболее простой вариант -- воспользоваться схемой:

# %% [markdown]
# <img src="scheme.png">

# %% [markdown]
# # Бот
#
# ## Бот, который присылает случайную картинку
# Требуется выбрать мессенджера, для которого вы будете реализовывать бота (VK, TG, FB, ...) и реализовать бота, который ожидает, пока пользователь с ним заговорит, после чего при получении сообщения от пользователя присылает ему случайную картинку из 10 заранее сохранённых в боте.
#
# ## Доклад о библиотеке для написания бота
# Подготовьте короткое (5-10 минут) сообщение о том, как пользоваться выбранной библиотекой. Вам нужно объяснить, как обрабатывать сообщение, получаемое от пользователя, как посылать своё, коротко рассказать о важных (на ваш взгляд) особенностях библиотеки. Рассчитывайте ваш доклад так, чтобы он был понятен вашим одноклассникам. Помните, что цель доклада -- сделать так, чтобы ваши одноклассники (которые не пишут бота) смогли быстро разобраться в библиотеке.
#
# ## Основная функциональность бота
# Бот обязательно должен уметь делать следующие вещи (возможно, ваша команда захочет добавить что-то ещё -- пожалуйста! Однако эти функции должны быть обязательно:
# * Бот должен при знакомстве с пользователем спрашивать 3-5 любимых жанров. Лучше сделать это в формате опроса: пользователю показывается, скажем, 10 картин разных жанров, и пользователь отмечает понравившиеся.
# * Бот должен также спрашивать, с какой частотой пользователя можно беспокоить. Некоторым захочется получать картины несколько раз в день, а некоторым не чаще раза в неделю.
# * Бот должен с заданной пользователем периодичностью присылать пользователю картины, их названия и, может быть, краткие описания.
# * Бот должен принимать у пользователя сообщения, которые будут трактоваться как названия картин, имена художников или сами картины. Для этого можно сделать кнопку (чтобы пользователь выбирал, что именно он хочет послать боту), а можно пытаться восстанавливать намерение пользователя как-то более интеллектуально. (Для примера можно посмотреть на бта Флибусты в тг)

# %% [markdown]
# # Парсер сайта
#
# ## Знакомство с WikiArt
#
# Зайдите на сайт https://www.wikiart.org/ru. Посмотрите на то, как сайт устроен, какие у него есть разделы и какие адреса имеют эти разделы.
# Установите библиотеку BeautifulSoup. Она поможет обрабатывать html-страницы.
# С помощью BeautifulSoup и requests скачайте с WikiArt список всех художников, которые представлены на сайте.
#
# ## Класс для взаимодействия с WikiArt
#
# Напишите класс, который будет обладать таким функционалом:
# * Умеет возвращать список всех художников и жанров
# * Умеет возвращать всех художников данного жанра
# * Умеет возвращать все картины (ссылки на картинки и их описания) данного художника
#
# Интерфейс класса должен быть как ниже.

# %%
class WikiArtHandler:
    def __init__(self):
        pass
    
    def get_genres(self):
        # возвращает список жанров
        pass
        
    def get_artists(self):
        # возвращает список художников
        pass
        
    def get_artists(self, genre):
        # возвращает список художников данного жанра
        pass
        
    def get_works(self, artist):
        # возвращает список всех работ данного художника
        pass

# %% [markdown]
# ## (*) Оптимизация взаимодействия с WikiArt
#
# Не вся информация, которая есть у WikiArtHandler, должна часто обновляться с сайта. Например, вряд ли новые художники появляются там очень быстро. Поэтому можно обдумать, какую информацию наиболее эффективно хранить на компьютере, а какую -- скачивать заново.

# %% [markdown]
# # Рекомендательная система
#
# Обратите внимание: класс, который здесь реализуется, отдельный для каждого пользователя.
#
# ## Наивные рекомендации
# Первое, что надо попробовать сделать -- рекомендовать пользователю просто случайные картины из работ тех художников, которые пользователю понравились.
# Скорее всего, такие рекомендации будут неплохим бейзлайном (то есть простым методом, который тем не менее даёт осмысленные результаты).
# Реализуйте класс Recommender со следующим функционалом:
# * Выдаёт следующую рекомендуемую картину (ссылку на изображение и его описание). То, как работает метод, должно, разумеется, зависеть от того, какая модель используется внутри класса.
# * Получает от пользователя (в широком смысле, т.е. от кода, который использует этот класс) данные о том, что какая-то картина понравилась.
#
# Интерфейс класса устроен так:

# %%
class Recommender:
    def __init__(self, user_id):
        # определяем нужные для модели параметры
        self.wikiart_handler = WikiArtHandler()
        
    def get_next(self):
        # выдаёт следующую рекомендуемую картину
        pass
        
    def update(self, picture):
        # обновляет внутреннее содержимое класса, чтобы улучшить рекомендации
        pass

# %% [markdown]
# ## Рекомендации посложнее
#
# Усложните модель на ваше усмотрение. Вот несколько идей, вы можете придумать и реализовать свои или выяснить, как это делают в настоящих проектах. Конечной целью является абстрактное счастье пользователя: чтобы пользователю было как можно интереснее взаимодействовать с ботом (и он не уходил).
#
# * Рекомендуйте не картины тех же художников, которых пользователь уже увидел и "лайкнул". Заранее посчитайте для каждого художника похожих (это могут быть мастера того же жанра, либо можно взять данные с каких-нибудь искусствоведческих сайтов), и рекомендуйте случайную картину из работ художника и похожих на него.
# * Используйте данные о том, как выглядят сами картины, чтобы определить похожие на них.
# * https://www.kaggle.com/gspmoreira/recommender-systems-in-python-101 (осторожно, это довольно сложно)
